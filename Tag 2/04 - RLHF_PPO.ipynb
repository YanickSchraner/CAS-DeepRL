# %% [markdown]
# # RLHF using trl
#
# For the docs, see [trl](https://huggingface.co/docs/trl/en/index).
#
# We use the [TL/DR Preference dataset](https://huggingface.co/datasets/trl-internal-testing/tldr-preference-sft-trl-style) in order to fine tune the [ElutherAI Pythia-1b LLM](https://huggingface.co/EleutherAI/pythia-1b-deduped) with [trl PPO fine tuning](https://huggingface.co/docs/trl/en/ppo_trainer).
#
#
# Here is an example Weights and Biases Experiment: https://wandb.ai/huggingface/trl/runs/dd2o3g35?nw=nwuserkrasul

# %%
# !pip install trl

# %%
# Download python script
# !wget https://raw.githubusercontent.com/huggingface/trl/c1e9ea8ecfdaf1486e2fc84bc55379b2338d5320/examples/scripts/ppo/ppo_tldr.py -O ppo_tldr.py

# %%
# !python ppo_tldr.py \
    --dataset_name trl-internal-testing/tldr-preference-sft-trl-style \
    --dataset_test_split validation \
    --learning_rate 3e-6 \
    --output_dir models/minimal/ppo_tldr \
    --per_device_train_batch_size 1 \
    --gradient_accumulation_steps 64 \
    --total_episodes 30000 \
    --model_name_or_path EleutherAI/pythia-1b-deduped \
    --sft_model_path cleanrl/EleutherAI_pythia-1b-deduped__sft__tldr \
    --reward_model_path cleanrl/EleutherAI_pythia-1b-deduped__reward__tldr \
    --missing_eos_penalty 1.0 \
    --stop_token eos \
    --response_length 53 \
    --eval_strategy steps \
    --eval_steps 100
